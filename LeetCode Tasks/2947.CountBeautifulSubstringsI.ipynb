# %%
from mpmath import inverse
from zipp.glob import separate


class Solution:
    def beautifulSubstrings(self, s: str, k: int) -> int:
        vowels = {'a', 'e', 'i', 'o', 'u'}
        
        count_vowels, count_consonants = 0, 0
        count_beautiful_substr = 0
        
        for i in range(len(s)):
            # ====================
            if s[i] in vowels:
                count_vowels += 1
                continue
            count_consonants+=1
            # ====================
            if count_vowels == count_consonants and (count_vowels*count_consonants)%k==0:
                count_beautiful_substr+=1
        print(count_beautiful_substr)       
        return count_vowels, count_consonants
    
# b a e y h

# %%
class Solution:
    def beautifulSubstrings(self, s: str, k: int) -> int:
        vowels = {'a', 'e', 'i', 'o', 'u'}
        
        if len(s)<=0:
            return 0
        
        if s[0] in vowels: is_vowel = True
        else: is_vowel = False
            
        separate_list = list()
        sub_str = s[0]
        for i in range(1,len(s)):
            # print(f'Iter - {i}:\n   Letter: {s[i]}')
            if (s[i] in vowels and not is_vowel):
                is_vowel = True
                separate_list.append(sub_str)
                sub_str = s[i]
                continue
            if (s[i] not in vowels and is_vowel):
                is_vowel = False
                separate_list.append(sub_str)
                sub_str = s[i]
                continue
            sub_str += s[i]
            # print(f'   Substring: {sub_str}')
        separate_list.append(sub_str)
        print(separate_list)
        count_sep = [len(sub_str) for sub_str in separate_list]
        print(count_sep)
        
        
        
        for i in range(0,len(separate_list),2):
            break
            
    
# b a e y h

# %%
s = "baeyh"
k = 2

# %%
s = "abba"
k = 1

# %%
Solution().beautifulSubstrings(s, k)
# Out:
# ['b', 'ae', 'yh']
# [1, 2, 2]

# %%
def count_sub_ab(s: str) -> int:
    count = 0
    for i in range(0,len(s)-1):
        substring = s[i:i+2]
        if substring == 'ab':
            count+=1
    return count

# %%
count_sub_ab('abba')
# Out:
# 1

# %%
[1,2,3]+[4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
result = list(map(lambda x, y: x + y, [1, 2, 3], [4, 5, 6]))
print(result)
# Out:
# [5, 7, 9]

# %%
data = [int(num) for num in input().split()]
min(data)
# Out:
# -1

# %%
1998/4
# Out:
# 499.5

# %%
def solution(year: int) -> bool:
    # put your python code here 
    if (year%4==0 and year%100!=0) or year%400==0:return True
    return False

print(solution(2020))
# Out:
# True

# %%
def solution(n: int) -> int:
    # put your python code here 
    if n==0: return 0
    if n==1: return 1
    return solution(n-1)+solution(n-2)

print(solution(int(input())))
# Out:
# 5

# %%
def solution(n: int) -> int:
    # put your python code here
    sqrt_5 = 5**(1/2)
    return int((((1+sqrt_5)/2)**n - ((1-sqrt_5)/2)**n)/sqrt_5)

print(solution(int(input())))
# Out:
# 13

# %%
string = 'true'
string[::-1]
# Out:
# 'eurt'

# %%
def solution(a_string: str) -> bool:
    # put your python code here
    if a_string == a_string[::-1] and len(a_string)!=0: return True
    return False

# %%
def solution(a_string: str) -> bool:
    # put your python code here 
    import string
    a_split = len(a_string)//2
    a_string = a_string.lower()
    a_string = [a_char for a_char in a_string if a_char not in string.punctuation]
    if a_string[:a_split] == a_string[-a_split:][::-1]: return True
    return False

# %%
print(solution('TOPPO!T'))
# Out:
# True

# %%
a_string = 'TOPPOT'
a_len = len(a_string)
# if a_len%2==0:
#     print(a_string[:a_len], a_len)
# else: print(a_string[:a_len], a_len)
a_split = a_len//2
a_string[:a_split], a_string[-a_split:][::-1],a_len
# Out:
# ('TOP', 'TOP', 6)
