# %%
import pandas as pd

# %%
def big_countries(world: pd.DataFrame) -> pd.DataFrame:
    new_world = world[(world['area'] >= 3000000) | (world['population'] >= 25000000)]
    new_world = new_world.drop(columns=['continent','gdp'])
    return new_world

# %%
data = [['Afghanistan', 'Asia', 652230, 25500100, 20343000000], ['Albania', 'Europe', 28748, 2831741, 12960000000], ['Algeria', 'Africa', 2381741, 37100000, 188681000000], ['Andorra', 'Europe', 468, 78115, 3712000000], ['Angola', 'Africa', 1246700, 20609294, 100990000000]]
world = pd.DataFrame(data, columns=['name', 'continent', 'area', 'population', 'gdp']).astype({'name':'object', 'continent':'object', 'area':'Int64', 'population':'Int64', 'gdp':'Int64'})

# %%
big_countries(world)
# Out:
#           name     area  population
# 0  Afghanistan   652230    25500100
# 2      Algeria  2381741    37100000

# %%
class Solution(object):
    def lengthOfLongestSubstring(self, s):
        if len(s) <= 1:
            return len(s)

        answer = ''
        now = ''
        for ch in s:
            if ch not in now:
                now += ch
            else:
                if len(now) > len(answer):
                    answer = now
                idx = now.index(ch)
                now = now[idx + 1:] + ch
        if len(now) > len(answer):
            answer = now

        return len(answer)

# %%
for i in range(len("abcabcbb")):
    print("abcabcbb"[i])
# Out:
# a
# b
# c
# a
# b
# c
# b
# b

# %%
Solution().lengthOfLongestSubstring("abcabcbb")
# Out:
# 3
